# %% [markdown]
# # **Preprocessing**

# %%
import os
from PIL import Image, ImageOps
import numpy as np
# !pip install opencv-python
import cv2
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 65.5 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.12.0.88

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from typing_extensions import Sized
input_images = "/content/drive/MyDrive/Raw Images"
output_images = "/content/drive/MyDrive/clean Images"
target_size = 512

# %%
os.makedirs(output_images, exist_ok=True)

# %%
#Crops the image to a centered square
def center_crop(img):
    width, height = img.size
    crop_size = min(width, height)

    left = (width - crop_size) // 2
    top = (height - crop_size) // 2
    right = left + crop_size
    bottom = top + crop_size

    return img.crop((left, top, right, bottom))

#Applies light normalization to even out brightness & contrast
def normalize_color(img):
    img_cv = np.array(img)
    img_yuv = cv2.cvtColor(img_cv, cv2.COLOR_RGB2YUV)

    # histogram equalization on the Y channel (brightness)
    img_yuv[:, :, 0] = cv2.equalizeHist(img_yuv[:, :, 0])

    img_norm = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2RGB)
    return Image.fromarray(img_norm)

#Re-saves the image without EXIF metadata
def remove_metadata(img):
    data = list(img.getdata())
    new_img = Image.new(img.mode, img.size)
    new_img.putdata(data)
    return new_img

# %%
for filename in os.listdir(input_images):
    if not filename.lower().endswith((".png", ".jpg", ".jpeg")):
        continue

    path = os.path.join(input_images, filename)

    try:
        img = Image.open(path).convert("RGB")

        # 1. Center Crop to Square
        img = center_crop(img)

        # 2. Resize to Target Size
        img = img.resize((target_size, target_size), Image.LANCZOS)

        # 3. Color & Contrast Normalization
        img = normalize_color(img)

        # 4. Remove EXIF Metadata
        img = remove_metadata(img)

        # 5. Save as PNG for quality
        output_path = os.path.join(
            output_images,
            os.path.splitext(filename)[0] + ".png"
        )
        img.save(output_path, format="PNG")

        print("Processed:", filename)

    except Exception as e:
        print("Error processing", filename, ":", e)
# Out:
# Processed: 25589701.jpg
# Processed: 28753061.jpg
# Processed: 22215229.jpg
# Processed: 22779038.jpg
# Processed: 19570587.jpg
# Processed: 16630920.jpg
# Processed: 21138719.jpg
# Processed: 25772368.jpg
# Processed: 16396183.jpg
# Processed: 23775702.jpg
# Processed: 24832988.jpg
# Processed: 19788551.jpg
# Processed: 19786858.jpg
# Processed: 19788552.jpg
# Processed: 18924662.jpg
# Processed: 27782020.jpg
# Processed: 24710703.jpg
# Processed: 22860067.jpg
# Processed: 23012662.jpg
# Processed: 17396786.jpg
# Processed: 17185253.jpg
# Processed: 21833287.jpg
# Processed: 27683428.jpg
# Processed: 26685105.jpg
# Processed: 29389675.jpg
# Processed: 23714402.jpg
# Processed: 26758039.jpg
# Processed: 28041138.jpg
# Processed: 16396193.jpg
# Processed: 24321674.jpg
# Processed: 17095593.jpg
# Processed: 25818051.jpg
# Processed: 20971288.jpg
# Processed: 23018702.jpg
# Processed: 23925202.jpg
# Processed: 17840997.jpg
# Processed: 22926817.jpg
# Processed: 26067618.jpg
# Processed: 24187497.jpg
# Processed: 24355644.jpg
# Processed: 17641927.jpg
# Processed: 20702864.jpg
# Processed: 18056405.jpg
# Processed: 26172759.jpg
# Processed: 30061114.jpg
# Processed: 23022402.jpg
# Processed: 27323284.jpg
# Processed: 24767513.jpg
# Processed: 20249851.jpg
# Processed: 19786861.jpg
# Processed: 17877225.jpg
# Processed: 29320965.jpg
# Processed: 25534384.jpg
# Processed: 23017965.jpg
# Processed: 22822422.jpg
# Processed: 20804307.jpg
# Processed: 20354191.jpg
# Processed: 19212715.jpg
# Processed: 18865365.jpg
# Processed: 22143604.jpg
# Processed: 24188477.jpg
# Processed: 18378347.jpg
# Processed: 19787273.jpg
# Processed: 17314123.jpg
# Processed: 23008270.jpg
# Processed: 22267437.jpg
# Processed: 16158623.jpg
# Processed: 21687074.jpg
# Processed: 16151663.jpg
# Processed: 19245206.jpg
# Processed: 24815360.jpg
# Processed: 16933558.jpg
# Processed: 18638962.jpg
# Processed: 17273391.jpg
# Processed: 19541210.jpg
# Processed: 26720379.jpg
# Processed: 21514026.jpg
# Processed: 16397322.jpg
# Processed: 20486069.jpg
# Processed: 24666160.jpg
# Processed: 28318358.jpg
# Processed: 25268657.jpg
# Processed: 24759839.jpg
# Processed: 28804571.jpg
# Processed: 24772114.jpg
# Processed: 16988097.jpg
# Processed: 17266976.jpg
# Processed: 18119750.jpg
# Processed: 26653224.jpg
# Processed: 26439066.jpg
# Processed: 23445819.jpg
# Processed: 22928793.jpg
# Processed: 29320312.jpg
# Processed: 24186977.jpg
# Processed: 28144507.jpg
# Processed: 29337734.jpg
# Processed: 23010569.jpg
# Processed: 23016091.jpg
# Processed: 16396205.jpg
# Processed: 23017628.jpg
# Processed: 21164875.jpg
# Processed: 22779916.jpg
# Processed: 16437914.jpg
# Processed: 16495609.jpg
# Processed: 27463274.jpg
# Processed: 20803565.jpg
# Processed: 20805896.jpg
# Processed: 23012542.jpg
# Processed: 16626851.jpg
# Processed: 17484203.jpg
# Processed: 30193039.jpg
# Processed: 21166859.jpg
# Processed: 23016250.jpg
# Processed: 28555944.jpg
# Processed: 19610188.jpg
# Processed: 25604966.jpg
# Processed: 25774845.jpg
# Processed: 22764427.jpg
# Processed: 29339871.jpg
# Processed: 21214696.jpg
# Processed: 19796500.jpg
# Processed: 23015940.jpg
# Processed: 23012579.jpg
# Processed: 18105594.jpg
# Processed: 15965185.jpg
# Processed: 18965154.jpg
# Processed: 18835207.jpg
# Processed: 20450474.jpg
# Processed: 23770160.jpg
# Processed: 17516940.jpg
# Processed: 24830572.jpg
# Processed: 20977655.jpg
# Processed: 23012796.jpg
# Processed: 22930048.jpg
# Processed: 16793868.jpg
# Processed: 26217061.jpg
# Processed: 23922298.jpg
# Processed: 24947103.jpg
# Processed: 19965828.jpg
# Processed: 25411181.jpg
# Processed: 24498061.jpg
# Processed: 19810652.jpg
# Processed: 18638572.jpg
# Processed: 18498385.jpg
# Processed: 24226660.jpg
# Processed: 16448369.jpg
# Processed: 24053752.jpg
# Processed: 18111123.jpg
# Processed: 17744613.jpg
# Processed: 20999014.jpg
# Processed: 24183660.jpg
# Processed: 23016347.jpg
# Processed: 19023618.jpg
# Processed: 23008408.jpg
# Processed: 17186135.jpg
# Processed: 19663663.jpg
# Processed: 26690039.jpg
# Processed: 23329858.jpg
# Processed: 22926358.jpg
# Processed: 23473996.jpg
# Processed: 27585638.jpg
# Processed: 23018379.jpg
# Processed: 19852513.jpg
# Processed: 24467676.jpg
# Processed: 29850055.jpg
# Processed: 24187978.jpg
# Processed: 19719902.jpg
# Processed: 26805148.jpg
# Processed: 29813421.jpg
# Processed: 23008340.jpg
# Processed: 21954377.jpg
# Processed: 24767778.jpg
# Processed: 24837637.jpg
# Processed: 27590618.jpg
# Processed: 23016221.jpg
# Processed: 24321040.jpg
# Processed: 19581538.jpg
# Processed: 23015660.jpg
# Processed: 21167868.jpg
# Processed: 24651801.jpg
# Processed: 18171073.jpg
# Processed: 24761526.jpg
# Processed: 18638574.jpg
# Processed: 18284727.jpg
# Processed: 19469520.jpg
# Processed: 19663315.jpg
# Processed: 16653104.jpg
# Processed: 16639719.jpg
# Processed: 16806669.jpg
# Processed: 19366040.jpg
# Processed: 19986766.jpg
# Processed: 21225351.jpg
# Processed: 21688595.jpg
# Processed: 24187380.jpg
# Processed: 25166900.jpg
# Processed: 25817944.jpg
# Processed: 26833964.jpg
# Processed: 26625117.jpg
# Processed: 27499590.jpg
# Processed: 28318644.jpg
